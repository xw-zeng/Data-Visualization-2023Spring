# %% [markdown]
# # Topic Modeling in Python and Interactive Visualization with pyLDAvis
#
# We will be using the 20 newsgroups dataset as provided by scikit-learn.

# %% [markdown]
# pip install pyLDAvis == 3.4.0
#
# pip install sklearn == 1.2.2
#
# 查看版本号：pyLDAvis.\_\_version\_\_

# %%
import pyLDAvis
import pyLDAvis.lda_model
pyLDAvis.enable_notebook()

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

import numpy as np
import sklearn

# %%
print(pyLDAvis.__version__)
print(sklearn.__version__)
# Out:
# 3.4.0
# 1.2.2

# %% [markdown]
# ## Load 20 newsgroups dataset
#
# First, the 20 newsgroups dataset available in sklearn is loaded. As always, the headers, footers and quotes are removed.

# %%
import pickle as pkl
docs_raw = pkl.load(open('20news.pkl', 'rb'))

# %%
len(docs_raw)
# Out:
# 3273

# %%
docs_raw[0]
# Out:
# "Hello World,\n\t     just bought a new Stealth two weeks ago. Got a grad student \n rebate. Someone told me that there's another $400 reabet for 1st time\n Chrysler buyer. True ? If yes can I still get it or am I too late ?\n"

# %% [markdown]
# ## Convert to document-term matrix
#
# Next, the raw documents are converted into document-term matrix, possibly as TF-IDF form.

# %%
tfidf_vectorizer = TfidfVectorizer(strip_accents = 'unicode',
                                   stop_words = 'english',
                                   lowercase = True,
                                   token_pattern = r'\b[a-zA-Z]{3,}\b',
                                   max_df = 0.5, 
                                   min_df = 10)
dtm_tfidf = tfidf_vectorizer.fit_transform(docs_raw)
print(dtm_tfidf.shape)
# Out:
# (3273, 3466)

# %% [markdown]
# ## Fit Latent Dirichlet Allocation models
#
# Finally, the LDA models are fitted.
#
# USE: sklearn.decomposition.LatentDirichletAllocation
#
# Refer to: https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.LatentDirichletAllocation.html

# %%
# TODO
lda = LatentDirichletAllocation(n_components=10)
lda.fit(dtm_tfidf)
# Out:
# LatentDirichletAllocation()

# %% [markdown]
# **Proportion of each topic in each document:**

# %%
# TODO
doc_topic = lda.transform(dtm_tfidf)

# %%
doc_topic.shape
# Out:
# (3273, 10)

# %%
doc_topic[0]
# Out:
# array([0.01999288, 0.0199928 , 0.01999293, 0.01999365, 0.01999625,
#        0.01999295, 0.01999286, 0.82004233, 0.01999491, 0.02000844])

# %% [markdown]
# **k word distributions (k topics):**

# %%
# TODO
topics = lda.components_
topics.shape
topics[1]
# Out:
# array([0.1       , 0.10000003, 0.10000001, ..., 0.10000001, 0.10000001,
#        0.10000003])

# %% [markdown]
# ## Visualizing the models with pyLDAvis

# %%
pyLDAvis.lda_model.prepare(lda, dtm_tfidf, tfidf_vectorizer)
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 7      0.037114 -0.167188       1        1  51.278249
# 9      0.273146  0.065983       2        1  16.377086
# 3     -0.085474  0.138710       3        1  12.438169
# 8     -0.051431  0.052685       4        1   5.681231
# 5     -0.015255 -0.008404       5        1   2.998705
# 0     -0.034613 -0.017681       6        1   2.390464
# 6     -0.038564 -0.015849       7        1   2.370354
# 2     -0.033204 -0.018282       8        1   2.287729
# 4     -0.030081 -0.016670       9        1   2.180355
# 1     -0.021637 -0.013304      10        1   1.997659, topic_info=          Term       Freq      Total Category  logprob  loglift
# 2900     space  33.000000  33.000000  Default  30.0000  30.0000
# 936      drive  32.000000  32.000000  Default  29.0000  29.0000
# 816    deleted  10.000000  10.000000  Default  28.0000  28.0000
# 2683      sale  27.000000  27.000000  Default  27.0000  27.0000
# 1806       mac  25.000000  25.000000  Default  26.0000  26.0000
# ...        ...        ...        ...      ...      ...      ...
# 717     course   0.989631  15.894827  Topic10  -5.7386   1.1368
# 2592  research   0.714308   7.768418  Topic10  -6.0646   1.5267
# 2759     sense   0.655077   6.722520  Topic10  -6.1512   1.5847
# 183    article   0.627777  12.941297  Topic10  -6.1937   0.8872
# 914      doing   0.610424  11.584661  Topic10  -6.2218   0.9699
#
# [508 rows x 6 columns], token_table=      Topic      Freq       Term
# term
# 49        5  0.823877  addresses
# 66        9  0.525693     affect
# 71        3  0.373520   agencies
# 71        9  0.373520   agencies
# 75        3  0.737647     agents
# ...     ...       ...        ...
# 3447      9  0.444419     writer
# 3456      1  0.736263       year
# 3456      2  0.138049       year
# 3456      3  0.046016       year
# 3456      4  0.046016       year
#
# [845 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[8, 10, 4, 9, 6, 1, 7, 3, 5, 2])
